# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import json
from pathlib import Path

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

data = requests.get(url)

crypto_prices = data.json()['Data']
crypto_df = pd.DataFrame(crypto_prices).transpose()
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# ...

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
file_path = Path('data/crypto_data.csv')
# Create a DataFrame
file_crypto_df = pd.read_csv(file_path, index_col=0)
file_crypto_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
extracted_crypto_df = file_crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
extracted_crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Keep only cryptocurrencies that are trading
extracted_crypto_df = extracted_crypto_df.loc[extracted_crypto_df['IsTrading'] == True, :]
extracted_crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Keep only cryptocurrencies with a working algorithm
extracted_crypto_df = extracted_crypto_df.loc[extracted_crypto_df['Algorithm'] != 'N/A', :]
extracted_crypto_df
# Out:
#          CoinName    Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42        42 Coin       Scrypt       True   PoW/PoS     4.199995e+01
# 365       365Coin          X11       True   PoW/PoS              NaN
# 404       404Coin       Scrypt       True   PoW/PoS     1.055185e+09
# 611     SixEleven      SHA-256       True       PoW              NaN
# 808           808      SHA-256       True   PoW/PoS     0.000000e+00
# ...           ...          ...        ...       ...              ...
# SERO   Super Zero       Ethash       True       PoW              NaN
# UOS           UOS      SHA-256       True      DPoI              NaN
# BDX        Beldex  CryptoNight       True       PoW     9.802226e+08
# ZEN       Horizen     Equihash       True       PoW     7.296538e+06
# XBC   BitcoinPlus       Scrypt       True       PoS     1.283270e+05
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...

# %%
# Remove the "IsTrading" column
extracted_crypto_df = extracted_crypto_df.drop(columns='IsTrading')
extracted_crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows with at least 1 null value

# %%
# Remove rows with cryptocurrencies having no coins mined

# %%
# Drop rows where there are 'N/A' text values

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm

# %%
# Create dummy variables for text features

# %%
# Standardize data

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components

# %%
# Create a DataFrame with the principal components data

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values


# Create the Elbow Curve using hvPlot

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model

# Fit the model

# Predict clusters

# Create a new DataFrame including predicted clusters and cryptocurrencies features

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

# %%
# Print the total number of tradable cryptocurrencies

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
